# %% [markdown]
# ### ⚽ Modelo YOLO
# Nosso modelo de **detecção de objetos**: será responsável por encontrar e classificar pessoas e objetos nas cenas contidas nos vídeos. Nesse caso, utilizarei o Ultralytics, justamente por se adaptar melhor ao modelo **livestream**
#
# **Por que Ultralytics?**
# > Confia

# %% [markdown]
# ![image.png](attachment:image.png)
